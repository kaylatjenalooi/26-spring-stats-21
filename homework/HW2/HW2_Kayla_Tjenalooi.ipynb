# %% [markdown]
# # Stats 21 - HW 2

# %% [markdown]
# # Kayla Tjenalooi

# %% [markdown]
# The questions have been entered into this document. You will modify the document by entering your code.
#
# Make sure you run the cell so the requested output is visible. Download/export it as an HTML file and then print to PDF. Be sure to tag your pages on Gradescope.
#
# **Homework is an opportunity to practice coding and to practice problem solving. Doing exercises is where you will do most of your learning.**
#
# **Using AI or copying someone else's solutions takes away your learning opportunities. It is also academic dishonesty.**

# %% [markdown]
# ## Reading
#
# - Think Python: Chapters 6 through 10
#
# **Reading is important!** Keep up with the reading. I recommend alternating between reading a chapter and then working on exercises.
#
# Additional recommended reading:
#
# - String methods documentation https://docs.python.org/3/library/stdtypes.html#string-methods

# %% [markdown]
# ## Textbook Chapter 5 Problems

# %% [markdown]
# ## Modified Exercise 5.14.2
#
# <https://allendowney.github.io/ThinkPython/chap05.html#exercise>

# %%
import time

# %%
time.time()
# Out:
# 1776877929.3576362

# %% [markdown]
# Write a function `now()` that reads the current time and prints out the time of day in hours, minutes, and
# seconds, plus the number of days since the epoch. The function does not need to return a value, just print output to the screen.
#
# The result should look like:
#
# "Current time is: 15:25:47. It has been 18370 days since the epoch."
#
# Use `int()` to drop decimal values. You do not need to try to find the date with years and months.
#
# Tip: build your function incrementally. Start by finding how many days have passed since the epoch. (check your answer at the bottom of the page: https://www.epochconverter.com/seconds-days-since-y0 )  From there find how many hours, etc. Keep in mind the hours will be UTC time.

# %%
def now():
    current = time.time()
    #integer division of seconds in a day to get days 
    days = int(current // (60*60*24))
    current = current % (60*60*24)

    #integer division of seconds in an hour 
    hours = int(current // 3600)
    current = current % 3600

    #integer division of seconds in a min

    minutes = int(current // 60)
    current = current % 60

    #leftover is seconds
    seconds = int(current)

    print(f"Current time is: {hours}:{minutes}:{seconds}. It has been {days} days since the epoch.")

# %%
now()
# Out:
# Current time is: 17:12:12. It has been 20565 days since the epoch.

# %% [markdown]
# ## Textbook Chapter 6 Problems

# %% [markdown]
# ## Modified Exercise 6.12.4
#
# <https://allendowney.github.io/ThinkPython/chap06.html#id2>
#
# The Ackermann function, A(m, n), is deﬁned:
#
# $$
# A(m, n)= \left \{
#     \begin{array}{ll}
#         n+1 & \text{if } m = 0\\
#         A(m-1, 1) & \text{if } m > 0 \text{ and } n = 0\\
#         A(m-1, A(m, n-1)) & \text{if } m > 0 \text{ and } n > 0\\
#     \end{array}
#  \right.
# $$
#
#
# See http://en.wikipedia.org/wiki/Ackermann_function . Write a function named `ack` that evaluates the Ackermann function. Use your function to evaluate a few test cases. Don't test with $m \ge 4$ as it grows very fast very quickly.

# %%
def ack(m,n):
    if m == 0:
        return n+1
    elif m > 0 and n == 0:
        return ack(m-1, 1)
    elif m > 0 and n > 0:
        return ack(m - 1, ack(m, n - 1))

# %%
# test case, should be 61
ack(3, 3)
# Out:
# 61

# %%
# test case, should be 125
ack(3, 4)
# Out:
# 125

# %% [markdown]
# ## Modified Exercise based on Think Python 2ed. Chap 6, Section 11, Exercise 6.4
#
# A number, `a`, is a power of `b` if it is divisible by `b` and `a/b` is a power of `b`. Write a function called `is_power` that takes parameters `a` and `b` and returns `True` if a is a power of b. Note: you will have to think about the base case.

# %%
def is_power(a, b):
    if a == 1: #any number to the power of 0 is one so this works 
        return True
    if a % b == 0: #divides it once 
        a = a / b #updates a to check it again 
        return is_power(a, b) 
    return False #default return if a is not one or a is not evenly divisible by b

# %%
is_power(1024, 2)
# Out:
# True

# %%
is_power(6561, 3)
# Out:
# True

# %%
is_power(4374, 3)
# Out:
# False

# %%
is_power(768, 2)
# Out:
# False

# %% [markdown]
# ## Modified Exercise 6.12.5
#
# <https://allendowney.github.io/ThinkPython/chap06.html#id3>
#
# The greatest common divisor (GCD) of a and b is the largest number that divides both of them with no remainder.
#
# One way to ﬁnd the GCD of two numbers is based on the observation that if `r` is the remainder when `a` is divided by `b`, then `gcd(a, b) = gcd(b, r)`.
#
# As a base case, we can use `gcd(a, 0) = a`.
#
# Write a function called `gcd` that takes parameters `a` and `b` and returns their greatest common divisor.

# %%
def gcd(a, b):
    # base case 
    if b == 0: # makes sure a isn't divisible by b 
        return a
    if b != 0: 
        r = a % b 
        return gcd(b, r)

# %%
gcd(21, 7)
# Out:
# 7

# %%
gcd(42, 28)
# Out:
# 14

# %%
gcd(105, 140)
# Out:
# 35

# %% [markdown]
# ## Textbook Chapter 7 Problems

# %% [markdown]
# ## Exercise 7.9.2
#
# <https://allendowney.github.io/ThinkPython/chap07.html#exercise>
#
# Write a function named `uses_none` that takes a word and a string of forbidden letters, and returns `True` if the word does not use any of the forbidden letters.
#
# Here's an outline of the function that includes two doctests. Fill in the function so it passes these tests, and add at least one more doctest.

# %%
def uses_none(word, forbidden):
    for letter in word: 
        for fletter in forbidden:
            if letter == fletter:
                return False
    return True

# %%
uses_none('banana', 'xyz')
# Out:
# True

# %%
uses_none('apple', 'efg')
# Out:
# False

# %%
uses_none('cloud', 'paint')
# Out:
# True

# %% [markdown]
# ## Exercise 7.9.3.
#
# <https://allendowney.github.io/ThinkPython/chap07.html#id1>
#
# Write a function called `uses_all` that takes a word and a string of letters, and that returns `True` if the word contains all of the letters in the string at least once.
#
# Here's an outline of the function that includes two doctests. Fill in the function so it passes these tests, and add at least one more doctest.

# %%
def uses_all(word, required):
    for letter in required:
        if letter not in word:
            return False
    return True

# %%
uses_all('banana', 'ban')
# Out:
# True

# %%
uses_all('apple', 'api')
# Out:
# False

# %%
uses_all('the quick brown fox jumps over the lazy dog', 'abcdefghijklmnopqrstuvwxyz')
# Out:
# True

# %% [markdown]
# ## Problems from Think Python 2nd Ed. Chapter 9

# %% [markdown]
# ## Exercise 9.1
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 84.
#
# Write and run a script that reads `words.txt` and prints out only the words with more than 20
# characters (after stripping whitespace).

# %%
fin = open("words.txt")
for line in fin:
    word = line.strip()
    if len(word) > 20:
        print(word)
# Out:
# counterdemonstrations
# hyperaggressivenesses
# microminiaturizations

# %% [markdown]
# ## Exercise 9.2
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 84.
#
# Write a function called `has_no_e` that returns True if the word doesn't have the letter e. You can use any of Pythons availble string methods.

# %%
def has_no_e(text):
    return not("E" in text or "e" in text)

# %%
has_no_e("hello")
# Out:
# False

# %%
has_no_e("quit")
# Out:
# True

# %% [markdown]
# With your function, write a script. The script should read the list of words (`words.txt`), print out the number of words that do not have the letter 'e' and the proportion of words that do not have the letter 'e'

# %%
fin = open("words.txt")
count = 0
total_words = 0
for line in fin: 
    total_words += 1
    word = line.strip()
    if has_no_e(word):
        count += 1

print(f"There are {count} words that do not have the letter 'e'. The proportion of words that do not have the letter 'e' is {count/total_words} ")
# Out:
# There are 37619 words that do not have the letter 'e'. The proportion of words that do not have the letter 'e' is 0.3306409084516946

# %% [markdown]
# ## Problems from Think Python 2nd Ed. Chapter 10

# %% [markdown]
# ## Exercise 10.1
#
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 100
#
#
# Write a function called `nested_sum` that takes a list of lists of integers and adds up
# the elements from all of the nested lists. For example:
# ```
# t = [[1, 2], [3], [4, 5, 6]]
# nested_sum(t)
# 21
# ```
# You may want to build the function recursively in case there are many levels of nested lists.
#
# You can assume that all elements in any of the nested lists are numeric.

# %%
def nested_sum(t):
    total = 0
    for item in t:
        if (type(item) == int):
            total += item
        else:
            total += nested_sum(item)
    return total

# %%
t = [1, 2]
nested_sum(t)
# Out:
# 3

# %%
t = [[1, 2], [3], [4, 5, 6]]
nested_sum(t)
# Out:
# 21

# %%
x = [[1, 2, [3]], 4, 5, 6, [7], 8]
nested_sum(x)
# Out:
# 36

# %%
t = [[[1, 2, [3]], [4, [5, 6, [7]], 8]]]
nested_sum(t)
# Out:
# 36

# %% [markdown]
# ## Exercise 10.2
#
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 100
#
# Write a function called `cumsum` that takes a list of numbers and returns the cumulative sum; that is, a new list where the ith element is the sum of the first i + 1 elements from the original list.
#
# For example:
# ```
# t = [1, 2, 3]
# cumsum(t)
# [1, 3, 6]
# ```
#
# You can assume that all elements in the lists are numeric and the list does not contain nested lists.

# %%
def cumsum(t):
    result = []
    csum = 0
    for num in t:
         csum = csum + num
         result.append(csum)

    return result

# %%
cumsum([1, 2, 3, 4])
# Out:
# [1, 3, 6, 10]

# %%
cumsum(range(12))
# Out:
# [0, 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66]

# %% [markdown]
# ## Exercise 10.6
#
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 101
#
# Two words are anagrams if you can rearrange the letters from one to spell the other. Write a function called `is_anagram` that takes two strings and returns `True` if they are anagrams.
#
# You can remove spaces and convert to lowercase using `string.replace(" ","").lower()`

# %%
def is_anagram(word1, word2):
    word1 = word1.replace(" ","").lower()
    word2 = word2.replace(" ","").lower()

    #sort the strings alphabetically
    word1 = sorted(word1)
    word2 = sorted(word2)

    return word1 == word2

# %%
is_anagram("hello", "o hell")
# Out:
# True

# %%
is_anagram("dormitory" , "dirty room")
# Out:
# True

# %%
is_anagram("dormitory" , "dirty rooms")
# Out:
# False

# %%
is_anagram("astronomers" , "moon starers")
# Out:
# True

# %% [markdown]
# ## Exercise 10.7
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 101
#
# Write a function called `has_duplicates` that takes a list and returns `True` if there is any element that appears more than once. It should not modify the original list.
#
# You can assume that the list will not have nested lists.

# %%
def has_duplicates(t):
    seen = []
    for item in t:
        if item in seen:
            return True
        else:
            seen.append(item)

    return False

# %%
has_duplicates(['a','b','c'])
# Out:
# False

# %%
has_duplicates(['a','b','b','c'])
# Out:
# True

# %%
has_duplicates(['a','b','c','a'])
# Out:
# True

# %% [markdown]
# ## Exercise 10.10
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 101
#
# To check whether a word is in the word list, you could use the in operator, but it would be slow because it searches through the words in order.
#
# Because the words are in alphabetical order, we can speed things up with a bisection search (also known as binary search). You start in the middle and check to see whether the word you are looking for comes before the word in the middle of the list. If so, you search the first half of the list the same way (perform a bisection search on the first half). Otherwise you search the second half.
#
# Either way, you cut the remaining search space in half. If the word list has 113,809 words, it will
# take about 17 steps to find the word or conclude that it's not there.
#
# Write a function called `in_bisect` that takes a sorted list and a target word and will returns `True` if the word is in the list and `False` if it's not.
#
# Hint: it's a recursive function.

# %%
# Use this function. No need to rewrite it.
def make_word_list():
    """Reads lines from a file and builds a list."""
    t = []
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        t.append(word)
    return t

t = make_word_list()

# %%
# define this function
def in_bisect(word_list, word):
    if len(word_list) == 0:
        return False
    
    #benchmark to set idx in the middle 
    idx = len(word_list) // 2
    
    if word_list[idx] == word:
        return True
    
    #look into first half of list
    if word_list[idx] > word:
        return in_bisect(word_list[:idx], word)
    
    #look into second half of list
    if word_list[idx] < word:
        return in_bisect(word_list[idx+1:], word)

# %%
in_bisect(t, "hello")
# Out:
# True

# %%
in_bisect(t, "xyz")
# Out:
# False

# %% [markdown]
# ## Exercise 10.11
#
# <https://greenteapress.com/thinkpython2/thinkpython2.pdf>
#
# Page 101
#
# Two words are a "reverse pair" if each is the reverse of the other.
#
# Now that you have the `in_bisect` search, write a script that ﬁnds all the reverse pairs in the word list that are 6 letters or longer. (It takes a little bit of time to run.)

# %%
### ('agenes', 'senega')
### ('animal', 'lamina')
### ...
### ('lamina', 'animal')
### ...
### ('senega', 'agenes')
### Because of the nature of a reverse pair, each pair will appear twice in the list

# %%
def rev_pair_finder(word_list, word):
    reversed = word[::-1]
    return in_bisect(word_list, reversed) #true if it exists 

for word in t:
    
    if rev_pair_finder(t, word):
        if len(word) >= 6: #make sure the word is longer than 6 chars
            print(word, word[::-1])
# Out:
# agenes senega
# animal lamina
# animes semina
# degami imaged
# deified deified
# deifier reified
# deliver reviled
# denier reined
# denies seined
# denned denned
# depots stoped
# derats stared
# dessert tressed
# desserts stressed
# dewans snawed
# dialer relaid
# diaper repaid
# dormin nimrod
# drawer reward
# elides sedile
# eviler relive
# gelder redleg
# halalah halalah
# hallah hallah
# imaged degami
# lamina animal
# levins snivel
# looter retool
# marram marram
# nimrod dormin
# pupils slipup
# recaps spacer
# redder redder
# redips spider
# redleg gelder
# redraw warder
# redrawer rewarder
# reflet telfer
# reflow wolfer
# reified deifier
# reifier reifier
# reined denier
# reknit tinker
# reknits stinker
# relaid dialer
# relive eviler
# remeet teemer
# rennet tenner
# repaid diaper
# repaper repaper
# repins sniper
# retool looter
# reviled deliver
# reviver reviver
# reward drawer
# rewarder redrawer
# rotator rotator
# sallets stellas
# scares seracs
# secret terces
# sedile elides
# seined denies
# selahs shales
# selles selles
# sememes sememes
# semina animes
# senega agenes
# seracs scares
# shales selahs
# skeets steeks
# sleeps speels
# sleets steels
# slipup pupils
# sloops spools
# snawed dewans
# sniper repins
# snivel levins
# snoops spoons
# spacer recaps
# speels sleeps
# spider redips
# spirts strips
# spools sloops
# spoons snoops
# sports strops
# sprits stirps
# stared derats
# steeks skeets
# steels sleets
# stellas sallets
# stinker reknits
# stirps sprits
# stoped depots
# stressed desserts
# strips spirts
# strops sports
# struts sturts
# sturts struts
# teemer remeet
# telfer reflet
# tenner rennet
# terces secret
# terret terret
# tinker reknit
# tressed dessert
# warder redraw
# wolfer reflow
